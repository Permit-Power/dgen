# %% [markdown]
# ### Export diffusion_results_* → per-state CSVs (parallel) and combine by state

# %%
# Set path to access helpers
from pathlib import Path
import sys

PARENT = Path.cwd().parent     # helpers live here
if str(PARENT) not in sys.path:
    sys.path.insert(0, str(PARENT))

# %%
from schema_exporter import ConnParams, export_all

# %%
OUT_DIR = "/Users/wael/Documents/dgen_runs"
RUN_ID  = "run_nc_single_state"

# %%
# DB connection (use env vars PGHOST, PGPORT, PGUSER, PGPASSWORD, PGDATABASE to override)
cp = ConnParams.from_env()  # or ConnParams(dbname="dgendb", user="postgres", ...)

# Choose parallelism
JOBS = 10

summary = export_all(
    cp=cp,
    out_dir=OUT_DIR,
    run_id=RUN_ID,
    chunksize=200_000,
    jobs=JOBS,
    overwrite=True,       
    only_scenarios=None,  
    states_filter=None, 
    schemas_include = ["diffusion_results_baseline_nc_2040_20260408_205828657932",
                       "diffusion_results_policy_nc_2040_20260408_210509801605"]
)

summary
# Out:
# /Users/wael/Documents/repos/dgen/dgen_os/python/schema_exporter.py:71: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(q, conn, params=(like_prefix + "%",))
# /Users/wael/Documents/repos/dgen/dgen_os/python/schema_exporter.py:249: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cols_df = pd.read_sql(meta_sql, conn, params=(schema_name,))
# /Users/wael/Documents/repos/dgen/dgen_os/python/schema_exporter.py:249: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cols_df = pd.read_sql(meta_sql, conn, params=(schema_name,))
# {'exported': ['diffusion_results_baseline_nc_2040_20260408_205828657932',
#   'diffusion_results_policy_nc_2040_20260408_210509801605'],
#  'skipped': [],
#  'failed': [],
#  'states': ['NC'],
#  'missing': []}
